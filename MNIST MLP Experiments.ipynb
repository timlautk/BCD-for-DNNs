# %% [markdown]
# # MLP on the MNIST Dataset

# %% [markdown]
# Trains two simple deep NNs on the MNIST dataset.
#
# Gets to 98% validation accuracy after 20 epochs (cross-entropy loss)
#
# Gets to 90.8% validation accuracy after 20 epochs (mean squared loss) (Residual Connection), 90.3% (MLP)
#
# Gets to 94.7% validation accuracy after 100 epochs (mean squared loss) (Residual Connection & MLP)
#
# (there is *a lot* of margin for parameter tuning).
#
# ~2 seconds per epoch on a GTX1070 GPU.

# %% [markdown]
# ## Import Tensorflow package (for Keras) and the MNIST dataset

# %%
from __future__ import print_function

# import keras
# from keras.datasets import mnist
# from keras.models import Sequential
# from keras.layers import Dense, Dropout
# from keras.optimizers import RMSprop
# from keras import regularizers

import tensorflow as tf

batch_size = 512
num_classes = 10
epochs = 100

# the data, shuffled and split between train and test sets
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)
# Out:
# 60000 train samples
# 10000 test samples

# %% [markdown]
# # The First Model (Residual Connection)

# %% [markdown]
# ## Model Setup

# %% [markdown]
# Input -> Fully Connected (2048) -> ReLU -> Fully Connected (784) -> Add Input -> ReLU -> Fully Connected (2048) -> ReLU -> Fully Connected (10) -> Mean squared loss

# %%
# model
x1 = tf.keras.layers.Input(shape=(784,))
a1 = tf.keras.layers.Dense(2048, activation='relu', use_bias=True)(x1)
a2 = tf.keras.layers.Dense(784, activation='relu', use_bias=True)(a1)
a2 = tf.keras.layers.Add()([a2, x1])
a3 = tf.keras.layers.Dense(2048, activation='relu', use_bias=True)(a2)
y_mlp = tf.keras.layers.Dense(num_classes, activation=None, use_bias=True)(a3)
#y_mlp = tf.keras.layers.Dense(num_classes, activation='softmax', use_bias=True, kernel_regularizer=tf.keras.regularizers.l2(l=0.01))(a3)

model = tf.keras.models.Model(inputs=x1, outputs=y_mlp)

model.summary()

model.compile(loss='mean_squared_error', optimizer='sgd', metrics=['accuracy'])
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 784)          0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2048)         1607680     input_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 784)          1606416     dense_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 784)          0           dense_2[0][0]
#                                                                  input_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 2048)         1607680     add_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 10)           20490       dense_3[0][0]
# ==================================================================================================
# Total params: 4,842,266
# Trainable params: 4,842,266
# Non-trainable params: 0
# __________________________________________________________________________________________________
# WARNING:tensorflow:From C:\Users\Tim Lau\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\tensorflow\python\keras\_impl\keras\backend.py:1557: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %% [markdown]
# ## Fit the Model using Back Propagation (Vanilla SGD)

# %%
history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
#print('Test error:', 1-score[1])
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
# 60000/60000 [==============================]60000/60000 [==============================] - 124s 2ms/step - loss: 0.0916 - acc: 0.3541 - val_loss: 0.0705 - val_acc: 0.6052
#
# Epoch 2/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 20us/step - loss: 0.0646 - acc: 0.6676 - val_loss: 0.0584 - val_acc: 0.7297
#
# Epoch 3/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0563 - acc: 0.7468 - val_loss: 0.0526 - val_acc: 0.7796
#
# Epoch 4/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 20us/step - loss: 0.0517 - acc: 0.7850 - val_loss: 0.0489 - val_acc: 0.8072
#
# Epoch 5/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0485 - acc: 0.8083 - val_loss: 0.0462 - val_acc: 0.8234
#
# Epoch 6/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0461 - acc: 0.8242 - val_loss: 0.0440 - val_acc: 0.8367
#
# Epoch 7/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0441 - acc: 0.8362 - val_loss: 0.0423 - val_acc: 0.8493
#
# Epoch 8/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0425 - acc: 0.8453 - val_loss: 0.0409 - val_acc: 0.8567
#
# Epoch 9/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0411 - acc: 0.8532 - val_loss: 0.0396 - val_acc: 0.8630
#
# Epoch 10/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0399 - acc: 0.8595 - val_loss: 0.0386 - val_acc: 0.8688
#
# Epoch 11/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0389 - acc: 0.8647 - val_loss: 0.0375 - val_acc: 0.8727
#
# Epoch 12/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0379 - acc: 0.8697 - val_loss: 0.0367 - val_acc: 0.8774
#
# Epoch 13/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0371 - acc: 0.8743 - val_loss: 0.0359 - val_acc: 0.8805
#
# Epoch 14/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0363 - acc: 0.8785 - val_loss: 0.0352 - val_acc: 0.8837
#
# Epoch 15/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 20us/step - loss: 0.0356 - acc: 0.8820 - val_loss: 0.0345 - val_acc: 0.8879
#
# Epoch 16/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0349 - acc: 0.8852 - val_loss: 0.0339 - val_acc: 0.8900
#
# Epoch 17/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0343 - acc: 0.8880 - val_loss: 0.0333 - val_acc: 0.8920
#
# Epoch 18/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0337 - acc: 0.8906 - val_loss: 0.0328 - val_acc: 0.8946
#
# Epoch 19/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0332 - acc: 0.8932 - val_loss: 0.0323 - val_acc: 0.8963
#
# Epoch 20/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0327 - acc: 0.8953 - val_loss: 0.0318 - val_acc: 0.8989
#
# Epoch 21/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 20us/step - loss: 0.0322 - acc: 0.8976 - val_loss: 0.0313 - val_acc: 0.9007
#
# Epoch 22/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 20us/step - loss: 0.0317 - acc: 0.8996 - val_loss: 0.0309 - val_acc: 0.9029
#
# Epoch 23/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0313 - acc: 0.9013 - val_loss: 0.0305 - val_acc: 0.9037
#
# Epoch 24/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 20us/step - loss: 0.0309 - acc: 0.9031 - val_loss: 0.0301 - val_acc: 0.9057
#
# Epoch 25/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0305 - acc: 0.9046 - val_loss: 0.0298 - val_acc: 0.9064
#
# Epoch 26/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0301 - acc: 0.9060 - val_loss: 0.0294 - val_acc: 0.9086
#
# Epoch 27/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0298 - acc: 0.9075 - val_loss: 0.0291 - val_acc: 0.9110
#
# Epoch 28/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0295 - acc: 0.9086 - val_loss: 0.0288 - val_acc: 0.9118
#
# Epoch 29/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 20us/step - loss: 0.0291 - acc: 0.9100 - val_loss: 0.0285 - val_acc: 0.9128
#
# Epoch 30/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 20us/step - loss: 0.0288 - acc: 0.9116 - val_loss: 0.0282 - val_acc: 0.9138
#
# Epoch 31/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 20us/step - loss: 0.0285 - acc: 0.9125 - val_loss: 0.0279 - val_acc: 0.9147
#
# Epoch 32/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 20us/step - loss: 0.0282 - acc: 0.9136 - val_loss: 0.0276 - val_acc: 0.9167
#
# Epoch 33/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0280 - acc: 0.9149 - val_loss: 0.0274 - val_acc: 0.9172
#
# Epoch 34/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 20us/step - loss: 0.0277 - acc: 0.9156 - val_loss: 0.0271 - val_acc: 0.9183
#
# Epoch 35/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 20us/step - loss: 0.0274 - acc: 0.9167 - val_loss: 0.0269 - val_acc: 0.9197
#
# Epoch 36/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 20us/step - loss: 0.0272 - acc: 0.9178 - val_loss: 0.0267 - val_acc: 0.9214
#
# Epoch 37/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 20us/step - loss: 0.0270 - acc: 0.9185 - val_loss: 0.0264 - val_acc: 0.9217
#
# Epoch 38/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 20us/step - loss: 0.0267 - acc: 0.9193 - val_loss: 0.0262 - val_acc: 0.9231
#
# Epoch 39/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0265 - acc: 0.9200 - val_loss: 0.0260 - val_acc: 0.9231
#
# Epoch 40/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0263 - acc: 0.9208 - val_loss: 0.0258 - val_acc: 0.9238
#
# Epoch 41/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 20us/step - loss: 0.0261 - acc: 0.9218 - val_loss: 0.0256 - val_acc: 0.9241
#
# Epoch 42/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 20us/step - loss: 0.0259 - acc: 0.9225 - val_loss: 0.0254 - val_acc: 0.9252
#
# Epoch 43/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 20us/step - loss: 0.0257 - acc: 0.9232 - val_loss: 0.0252 - val_acc: 0.9259
#
# Epoch 44/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0255 - acc: 0.9243 - val_loss: 0.0250 - val_acc: 0.9263
#
# Epoch 45/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 20us/step - loss: 0.0253 - acc: 0.9249 - val_loss: 0.0249 - val_acc: 0.9272
#
# Epoch 46/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 20us/step - loss: 0.0251 - acc: 0.9256 - val_loss: 0.0247 - val_acc: 0.9277
#
# Epoch 47/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 20us/step - loss: 0.0250 - acc: 0.9261 - val_loss: 0.0246 - val_acc: 0.9284
#
# Epoch 48/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 20us/step - loss: 0.0248 - acc: 0.9269 - val_loss: 0.0244 - val_acc: 0.9286
#
# Epoch 49/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 20us/step - loss: 0.0246 - acc: 0.9272 - val_loss: 0.0242 - val_acc: 0.9293
#
# Epoch 50/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 20us/step - loss: 0.0245 - acc: 0.9280 - val_loss: 0.0241 - val_acc: 0.9305
#
# Epoch 51/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0243 - acc: 0.9285 - val_loss: 0.0239 - val_acc: 0.9306
#
# Epoch 52/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0242 - acc: 0.9292 - val_loss: 0.0238 - val_acc: 0.9314
#
# Epoch 53/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 20us/step - loss: 0.0240 - acc: 0.9299 - val_loss: 0.0237 - val_acc: 0.9312
#
# Epoch 54/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 20us/step - loss: 0.0239 - acc: 0.9303 - val_loss: 0.0235 - val_acc: 0.9324
#
# Epoch 55/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 20us/step - loss: 0.0237 - acc: 0.9307 - val_loss: 0.0234 - val_acc: 0.9326
#
# Epoch 56/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 20us/step - loss: 0.0236 - acc: 0.9312 - val_loss: 0.0233 - val_acc: 0.9330
#
# Epoch 57/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 20us/step - loss: 0.0234 - acc: 0.9317 - val_loss: 0.0231 - val_acc: 0.9330
#
# Epoch 58/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 20us/step - loss: 0.0233 - acc: 0.9325 - val_loss: 0.0230 - val_acc: 0.9340
#
# Epoch 59/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 20us/step - loss: 0.0232 - acc: 0.9328 - val_loss: 0.0229 - val_acc: 0.9338
#
# Epoch 60/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 22us/step - loss: 0.0231 - acc: 0.9334 - val_loss: 0.0228 - val_acc: 0.9339
#
# Epoch 61/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0229 - acc: 0.9338 - val_loss: 0.0227 - val_acc: 0.9345
#
# Epoch 62/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0228 - acc: 0.9344 - val_loss: 0.0226 - val_acc: 0.9350
#
# Epoch 63/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0227 - acc: 0.9348 - val_loss: 0.0225 - val_acc: 0.9357
#
# Epoch 64/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 20us/step - loss: 0.0226 - acc: 0.9354 - val_loss: 0.0224 - val_acc: 0.9353
#
# Epoch 65/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 20us/step - loss: 0.0225 - acc: 0.9358 - val_loss: 0.0223 - val_acc: 0.9358
#
# Epoch 66/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0224 - acc: 0.9363 - val_loss: 0.0222 - val_acc: 0.9361
#
# Epoch 67/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0222 - acc: 0.9368 - val_loss: 0.0220 - val_acc: 0.9370
#
# Epoch 68/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 20us/step - loss: 0.0221 - acc: 0.9374 - val_loss: 0.0219 - val_acc: 0.9370
#
# Epoch 69/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 20us/step - loss: 0.0220 - acc: 0.9376 - val_loss: 0.0219 - val_acc: 0.9384
#
# Epoch 70/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 20us/step - loss: 0.0219 - acc: 0.9381 - val_loss: 0.0218 - val_acc: 0.9378
#
# Epoch 71/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0218 - acc: 0.9384 - val_loss: 0.0217 - val_acc: 0.9376
#
# Epoch 72/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0217 - acc: 0.9387 - val_loss: 0.0216 - val_acc: 0.9392
#
# Epoch 73/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 20us/step - loss: 0.0216 - acc: 0.9391 - val_loss: 0.0215 - val_acc: 0.9394
#
# Epoch 74/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 20us/step - loss: 0.0215 - acc: 0.9397 - val_loss: 0.0214 - val_acc: 0.9405
#
# Epoch 75/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0215 - acc: 0.9401 - val_loss: 0.0213 - val_acc: 0.9400
#
# Epoch 76/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0214 - acc: 0.9406 - val_loss: 0.0212 - val_acc: 0.9406
#
# Epoch 77/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0213 - acc: 0.9408 - val_loss: 0.0212 - val_acc: 0.9410
#
# Epoch 78/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0212 - acc: 0.9411 - val_loss: 0.0211 - val_acc: 0.9412
#
# Epoch 79/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 20us/step - loss: 0.0211 - acc: 0.9414 - val_loss: 0.0210 - val_acc: 0.9413
#
# Epoch 80/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0210 - acc: 0.9420 - val_loss: 0.0209 - val_acc: 0.9424
#
# Epoch 81/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0209 - acc: 0.9423 - val_loss: 0.0208 - val_acc: 0.9420
#
# Epoch 82/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0208 - acc: 0.9427 - val_loss: 0.0208 - val_acc: 0.9431
#
# Epoch 83/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0208 - acc: 0.9428 - val_loss: 0.0207 - val_acc: 0.9425
#
# Epoch 84/100
# 60000/60000 [==============================]60000/60000 [==============================] - ETA: 0s - loss: 0.0207 - acc: 0.943 - 1s 19us/step - loss: 0.0207 - acc: 0.9434 - val_loss: 0.0206 - val_acc: 0.9432
#
# Epoch 85/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0206 - acc: 0.9436 - val_loss: 0.0205 - val_acc: 0.9434
#
# Epoch 86/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0205 - acc: 0.9438 - val_loss: 0.0205 - val_acc: 0.9433
#
# Epoch 87/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0204 - acc: 0.9442 - val_loss: 0.0204 - val_acc: 0.9436
#
# Epoch 88/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0204 - acc: 0.9445 - val_loss: 0.0203 - val_acc: 0.9434
#
# Epoch 89/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0203 - acc: 0.9449 - val_loss: 0.0203 - val_acc: 0.9446
#
# Epoch 90/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0202 - acc: 0.9450 - val_loss: 0.0202 - val_acc: 0.9441
#
# Epoch 91/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0202 - acc: 0.9453 - val_loss: 0.0202 - val_acc: 0.9438
#
# Epoch 92/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 18us/step - loss: 0.0201 - acc: 0.9457 - val_loss: 0.0201 - val_acc: 0.9448
#
# Epoch 93/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0200 - acc: 0.9460 - val_loss: 0.0200 - val_acc: 0.9447
#
# Epoch 94/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0199 - acc: 0.9461 - val_loss: 0.0199 - val_acc: 0.9456
#
# Epoch 95/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0199 - acc: 0.9464 - val_loss: 0.0199 - val_acc: 0.9454
#
# Epoch 96/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0198 - acc: 0.9466 - val_loss: 0.0198 - val_acc: 0.9459
#
# Epoch 97/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0197 - acc: 0.9468 - val_loss: 0.0198 - val_acc: 0.9456
#
# Epoch 98/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0197 - acc: 0.9470 - val_loss: 0.0197 - val_acc: 0.9459
#
# Epoch 99/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0196 - acc: 0.9473 - val_loss: 0.0196 - val_acc: 0.9457
#
# Epoch 100/100
# 60000/60000 [==============================]60000/60000 [==============================] - 1s 19us/step - loss: 0.0196 - acc: 0.9476 - val_loss: 0.0196 - val_acc: 0.9460
#
# Test loss: 0.01957503787279129
# Test accuracy: 0.946

# %% [markdown]
# ## Loss and Accuracy Plots

# %%
# Plot of Losses
import matplotlib.pyplot as plt

history_dict = history.history
# history_dict.keys()
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
acc_values = history_dict['acc']
val_acc_values = history_dict['val_acc']

epochs_index = range(1,len(loss_values)+1)

fig_loss = plt.figure(figsize=(6, 6))
plt.plot(epochs_index, loss_values, 'b', label='Training loss')
plt.plot(epochs_index, val_loss_values, 'b', c='orange', label='Validation loss')
plt.title('Three-layer Fully-connected Network (2nd ResNet Hidden Layer)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()



#%%
# Plot of Accuracy
plt.clf()
fig_accuracy = plt.figure(figsize=(6, 6))
plt.plot(epochs_index,acc_values,'b', label='Training accuracy')
plt.plot(epochs_index,val_acc_values,'b', c='orange', label='Validation accuracy')
plt.title('Three-layer Fully-connected Network (2nd ResNet Hidden Layer)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %% [markdown]
# ## Save the Plots

# %%
fig_accuracy.savefig('fig_accuracy.eps', format='eps', dpi=2000)

# %% [markdown]
# # The Second Model (MLP)

# %% [markdown]
# ## Model Setup

# %% [markdown]
# Input -> Fully Connected (2048) -> ReLU -> Fully Connected (2048) -> ReLU -> Fully Connected (2048) -> ReLU -> Fully Connected (10) -> Mean squared loss

# %%
# model
x0 = tf.keras.layers.Input(shape=(784,))
u1 = tf.keras.layers.Dense(2048, activation='relu', use_bias=True)(x0)
u2 = tf.keras.layers.Dense(2048, activation='relu', use_bias=True)(u1)
u3 = tf.keras.layers.Dense(2048, activation='relu', use_bias=True)(u2)
y_mlp_2 = tf.keras.layers.Dense(num_classes, activation=None, use_bias=True)(u3)
#y_mlp = tf.keras.layers.Dense(num_classes, activation='softmax', use_bias=True, kernel_regularizer=tf.keras.regularizers.l2(l=0.01))(a3)

model_2 = tf.keras.models.Model(inputs=x0, outputs=y_mlp_2)

model_2.summary()

model_2.compile(loss='mean_squared_error', optimizer='sgd', metrics=['accuracy'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 784)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 2048)              1607680
# _________________________________________________________________
# dense_6 (Dense)              (None, 2048)              4196352
# _________________________________________________________________
# dense_7 (Dense)              (None, 2048)              4196352
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                20490
# =================================================================
# Total params: 10,020,874
# Trainable params: 10,020,874
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Fit the Model using Back Propagation (Vanilla SGD)

# %%
history_2 = model_2.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score_2 = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score_2[0])
print('Test accuracy:', score_2[1])
#print('Test error:', 1-score[1])
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 30us/step - loss: 0.0850 - acc: 0.3531 - val_loss: 0.0727 - val_acc: 0.5957
#
# Epoch 2/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0667 - acc: 0.6727 - val_loss: 0.0604 - val_acc: 0.7382
#
# Epoch 3/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0573 - acc: 0.7585 - val_loss: 0.0533 - val_acc: 0.7925
#
# Epoch 4/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0516 - acc: 0.7942 - val_loss: 0.0487 - val_acc: 0.8187
#
# Epoch 5/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0479 - acc: 0.8150 - val_loss: 0.0456 - val_acc: 0.8326
#
# Epoch 6/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0451 - acc: 0.8302 - val_loss: 0.0432 - val_acc: 0.8449
#
# Epoch 7/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0430 - acc: 0.8408 - val_loss: 0.0413 - val_acc: 0.8578
#
# Epoch 8/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0413 - acc: 0.8492 - val_loss: 0.0398 - val_acc: 0.8638
#
# Epoch 9/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0399 - acc: 0.8572 - val_loss: 0.0385 - val_acc: 0.8698
#
# Epoch 10/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0387 - acc: 0.8627 - val_loss: 0.0373 - val_acc: 0.8754
#
# Epoch 11/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0376 - acc: 0.8677 - val_loss: 0.0363 - val_acc: 0.8815
#
# Epoch 12/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0366 - acc: 0.8727 - val_loss: 0.0354 - val_acc: 0.8835
#
# Epoch 13/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0358 - acc: 0.8766 - val_loss: 0.0346 - val_acc: 0.8857
#
# Epoch 14/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0350 - acc: 0.8802 - val_loss: 0.0338 - val_acc: 0.8893
#
# Epoch 15/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0343 - acc: 0.8840 - val_loss: 0.0331 - val_acc: 0.8929
#
# Epoch 16/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0336 - acc: 0.8869 - val_loss: 0.0325 - val_acc: 0.8959
#
# Epoch 17/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0330 - acc: 0.8895 - val_loss: 0.0319 - val_acc: 0.8994
#
# Epoch 18/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0324 - acc: 0.8921 - val_loss: 0.0313 - val_acc: 0.9009
#
# Epoch 19/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0319 - acc: 0.8943 - val_loss: 0.0308 - val_acc: 0.9041
#
# Epoch 20/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0314 - acc: 0.8967 - val_loss: 0.0304 - val_acc: 0.9058
#
# Epoch 21/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0309 - acc: 0.8988 - val_loss: 0.0299 - val_acc: 0.9059
#
# Epoch 22/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0304 - acc: 0.9007 - val_loss: 0.0295 - val_acc: 0.9091
#
# Epoch 23/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0300 - acc: 0.9020 - val_loss: 0.0291 - val_acc: 0.9105
#
# Epoch 24/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0296 - acc: 0.9038 - val_loss: 0.0287 - val_acc: 0.9120
#
# Epoch 25/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0292 - acc: 0.9053 - val_loss: 0.0283 - val_acc: 0.9140
#
# Epoch 26/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0288 - acc: 0.9070 - val_loss: 0.0279 - val_acc: 0.9146
#
# Epoch 27/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0285 - acc: 0.9084 - val_loss: 0.0276 - val_acc: 0.9162
#
# Epoch 28/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0281 - acc: 0.9098 - val_loss: 0.0273 - val_acc: 0.9170
#
# Epoch 29/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0278 - acc: 0.9108 - val_loss: 0.0270 - val_acc: 0.9184
#
# Epoch 30/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0275 - acc: 0.9122 - val_loss: 0.0267 - val_acc: 0.9188
#
# Epoch 31/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0272 - acc: 0.9133 - val_loss: 0.0264 - val_acc: 0.9193
#
# Epoch 32/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0269 - acc: 0.9145 - val_loss: 0.0261 - val_acc: 0.9197
#
# Epoch 33/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0266 - acc: 0.9154 - val_loss: 0.0258 - val_acc: 0.9204
#
# Epoch 34/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0264 - acc: 0.9166 - val_loss: 0.0256 - val_acc: 0.9213
#
# Epoch 35/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0261 - acc: 0.9174 - val_loss: 0.0253 - val_acc: 0.9213
#
# Epoch 36/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0258 - acc: 0.9186 - val_loss: 0.0251 - val_acc: 0.9225
#
# Epoch 37/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0256 - acc: 0.9196 - val_loss: 0.0249 - val_acc: 0.9234
#
# Epoch 38/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0254 - acc: 0.9204 - val_loss: 0.0247 - val_acc: 0.9252
#
# Epoch 39/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0251 - acc: 0.9217 - val_loss: 0.0244 - val_acc: 0.9253
#
# Epoch 40/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0249 - acc: 0.9223 - val_loss: 0.0242 - val_acc: 0.9263
#
# Epoch 41/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0247 - acc: 0.9232 - val_loss: 0.0240 - val_acc: 0.9268
#
# Epoch 42/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0245 - acc: 0.9237 - val_loss: 0.0238 - val_acc: 0.9276
#
# Epoch 43/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0243 - acc: 0.9245 - val_loss: 0.0237 - val_acc: 0.9280
#
# Epoch 44/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0241 - acc: 0.9256 - val_loss: 0.0235 - val_acc: 0.9290
#
# Epoch 45/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0239 - acc: 0.9264 - val_loss: 0.0233 - val_acc: 0.9297
#
# Epoch 46/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0237 - acc: 0.9269 - val_loss: 0.0231 - val_acc: 0.9302
#
# Epoch 47/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0236 - acc: 0.9276 - val_loss: 0.0230 - val_acc: 0.9315
#
# Epoch 48/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0234 - acc: 0.9284 - val_loss: 0.0228 - val_acc: 0.9324
#
# Epoch 49/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0232 - acc: 0.9287 - val_loss: 0.0226 - val_acc: 0.9328
#
# Epoch 50/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0231 - acc: 0.9296 - val_loss: 0.0225 - val_acc: 0.9337
#
# Epoch 51/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0229 - acc: 0.9302 - val_loss: 0.0223 - val_acc: 0.9343
#
# Epoch 52/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0227 - acc: 0.9306 - val_loss: 0.0222 - val_acc: 0.9354
#
# Epoch 53/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0226 - acc: 0.9313 - val_loss: 0.0221 - val_acc: 0.9362
#
# Epoch 54/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0224 - acc: 0.9319 - val_loss: 0.0219 - val_acc: 0.9364
#
# Epoch 55/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0223 - acc: 0.9323 - val_loss: 0.0218 - val_acc: 0.9361
#
# Epoch 56/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0222 - acc: 0.9331 - val_loss: 0.0217 - val_acc: 0.9377
#
# Epoch 57/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0220 - acc: 0.9337 - val_loss: 0.0215 - val_acc: 0.9378
#
# Epoch 58/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0219 - acc: 0.9341 - val_loss: 0.0214 - val_acc: 0.9375
#
# Epoch 59/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0218 - acc: 0.9348 - val_loss: 0.0213 - val_acc: 0.9381
#
# Epoch 60/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0216 - acc: 0.9350 - val_loss: 0.0212 - val_acc: 0.9387
#
# Epoch 61/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0215 - acc: 0.9355 - val_loss: 0.0211 - val_acc: 0.9383
#
# Epoch 62/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0214 - acc: 0.9359 - val_loss: 0.0209 - val_acc: 0.9392
#
# Epoch 63/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0213 - acc: 0.9366 - val_loss: 0.0208 - val_acc: 0.9395
#
# Epoch 64/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0211 - acc: 0.9368 - val_loss: 0.0207 - val_acc: 0.9399
#
# Epoch 65/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0210 - acc: 0.9373 - val_loss: 0.0206 - val_acc: 0.9401
#
# Epoch 66/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0209 - acc: 0.9377 - val_loss: 0.0205 - val_acc: 0.9407
#
# Epoch 67/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0208 - acc: 0.9383 - val_loss: 0.0204 - val_acc: 0.9409
#
# Epoch 68/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0207 - acc: 0.9388 - val_loss: 0.0203 - val_acc: 0.9408
#
# Epoch 69/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0206 - acc: 0.9392 - val_loss: 0.0202 - val_acc: 0.9412
#
# Epoch 70/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0205 - acc: 0.9393 - val_loss: 0.0201 - val_acc: 0.9418
#
# Epoch 71/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0204 - acc: 0.9399 - val_loss: 0.0200 - val_acc: 0.9415
#
# Epoch 72/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0203 - acc: 0.9402 - val_loss: 0.0199 - val_acc: 0.9421
#
# Epoch 73/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0202 - acc: 0.9407 - val_loss: 0.0198 - val_acc: 0.9424
#
# Epoch 74/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0201 - acc: 0.9410 - val_loss: 0.0198 - val_acc: 0.9423
#
# Epoch 75/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0200 - acc: 0.9414 - val_loss: 0.0197 - val_acc: 0.9427
#
# Epoch 76/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0199 - acc: 0.9418 - val_loss: 0.0196 - val_acc: 0.9428
#
# Epoch 77/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0198 - acc: 0.9420 - val_loss: 0.0195 - val_acc: 0.9428
#
# Epoch 78/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0197 - acc: 0.9422 - val_loss: 0.0194 - val_acc: 0.9430
#
# Epoch 79/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0196 - acc: 0.9427 - val_loss: 0.0194 - val_acc: 0.9433
#
# Epoch 80/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0196 - acc: 0.9430 - val_loss: 0.0193 - val_acc: 0.9434
#
# Epoch 81/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0195 - acc: 0.9433 - val_loss: 0.0192 - val_acc: 0.9436
#
# Epoch 82/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0194 - acc: 0.9436 - val_loss: 0.0191 - val_acc: 0.9441
#
# Epoch 83/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 27us/step - loss: 0.0193 - acc: 0.9439 - val_loss: 0.0190 - val_acc: 0.9442
#
# Epoch 84/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0192 - acc: 0.9442 - val_loss: 0.0190 - val_acc: 0.9442
#
# Epoch 85/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0191 - acc: 0.9443 - val_loss: 0.0189 - val_acc: 0.9444
#
# Epoch 86/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0191 - acc: 0.9449 - val_loss: 0.0188 - val_acc: 0.9445
#
# Epoch 87/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0190 - acc: 0.9450 - val_loss: 0.0188 - val_acc: 0.9452
#
# Epoch 88/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0189 - acc: 0.9453 - val_loss: 0.0187 - val_acc: 0.9449
#
# Epoch 89/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0188 - acc: 0.9456 - val_loss: 0.0186 - val_acc: 0.9454
#
# Epoch 90/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0188 - acc: 0.9459 - val_loss: 0.0186 - val_acc: 0.9449
#
# Epoch 91/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0187 - acc: 0.9463 - val_loss: 0.0185 - val_acc: 0.9454
#
# Epoch 92/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0186 - acc: 0.9464 - val_loss: 0.0184 - val_acc: 0.9457
#
# Epoch 93/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0186 - acc: 0.9470 - val_loss: 0.0184 - val_acc: 0.9457
#
# Epoch 94/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0185 - acc: 0.9471 - val_loss: 0.0183 - val_acc: 0.9460
#
# Epoch 95/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0184 - acc: 0.9474 - val_loss: 0.0182 - val_acc: 0.9466
#
# Epoch 96/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0184 - acc: 0.9476 - val_loss: 0.0182 - val_acc: 0.9466
#
# Epoch 97/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0183 - acc: 0.9477 - val_loss: 0.0181 - val_acc: 0.9460
#
# Epoch 98/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0182 - acc: 0.9480 - val_loss: 0.0181 - val_acc: 0.9467
#
# Epoch 99/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0182 - acc: 0.9482 - val_loss: 0.0180 - val_acc: 0.9470
#
# Epoch 100/100
# 60000/60000 [==============================]60000/60000 [==============================] - 2s 28us/step - loss: 0.0181 - acc: 0.9485 - val_loss: 0.0179 - val_acc: 0.9466
#
# Test loss: 0.01957503787279129
# Test accuracy: 0.946

# %% [markdown]
# ## Loss and Accuracy Plots

# %%
# Plot of Losses
import matplotlib.pyplot as plt

history_dict_2 = history_2.history
# history_dict.keys()
loss_values_2 = history_dict_2['loss']
val_loss_values_2 = history_dict_2['val_loss']
acc_values_2 = history_dict_2['acc']
val_acc_values_2 = history_dict_2['val_acc']

epochs = range(1,len(loss_values)+1)
fig_loss_2 = plt.figure(figsize=(6, 6))
plt.plot(epochs_index, loss_values_2, 'b', label='Training loss')
plt.plot(epochs_index, val_loss_values_2, 'b', c='orange', label='Validation loss')
plt.title('Three-layer MLP')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()



#%%
# Plot of Accuracy
plt.clf()
fig_accuracy_2 = plt.figure(figsize=(6, 6))
plt.plot(epochs_index,acc_values_2,'b', label='Training accuracy')
plt.plot(epochs_index,val_acc_values_2,'b', c='orange', label='Validation accuracy')
plt.title('Three-layer MLP')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %% [markdown]
# ## Save the Plots

# %%
fig_accuracy_2.savefig('fig_accuracy_2.eps', format='eps', dpi=2000)
